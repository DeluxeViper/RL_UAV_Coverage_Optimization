# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import matplotlib.pyplot as plt
from collections import deque
from sklearn.cluster import KMeans
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
import time
from IPython.display import clear_output

# %%
print (np.random.uniform(-1, 1))
# Out:
# -0.45006074216105985

# %%
# Define the Q-Network using a simple feedforward neural network
class QNetwork(nn.Module):
    def __init__(self, state_size, action_size):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(state_size, 128)  # Increased neurons for better GPU utilization
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_size)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten the input tensor
        x = F.leaky_relu(self.fc1(x)) # Optimized for GPU
        x = F.leaky_relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=10000)
        self.gamma = 0.99
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995  # Slower decay to increase exploration
        self.learning_rate = 0.0001
        self.batch_size = 64
        self.model = QNetwork(state_size, action_size).to(device)
        self.target_model = QNetwork(state_size, action_size).to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()
        self.update_target_model()

    def update_target_model(self):
        self.target_model.load_state_dict(self.model.state_dict())

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return [random.randrange(n) for n in env.action_space.nvec]
        state = torch.FloatTensor(state.flatten()).unsqueeze(0).to(device)
        act_values = self.model(state)
        action = torch.argmax(act_values[0]).item()
        return np.unravel_index(action, env.action_space.nvec)

    def replay(self):
        if len(self.memory) < self.batch_size:
            return
        minibatch = random.sample(self.memory, self.batch_size)
        states, actions, rewards, next_states, dones = zip(*minibatch)

        states = torch.FloatTensor(states).to(device)
        next_states = torch.FloatTensor(next_states).to(device)
        rewards = torch.FloatTensor(rewards).to(device)
        dones = torch.FloatTensor(dones).to(device)

        q_values = self.model(states)
        next_q_values = self.target_model(next_states)
        q_target = q_values.clone()

        for i in range(self.batch_size):
            q_target[i, np.ravel_multi_index(actions[i], env.action_space.nvec)] = rewards[i] + (self.gamma * torch.max(next_q_values[i]) * (1 - dones[i]))

        self.optimizer.zero_grad()
        loss = self.criterion(q_values, q_target)
        loss.backward()
        self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        return loss.item()

# %%
class UAVClusterEnv(gym.Env):
    def __init__(self, num_users=10, num_uavs=2, area_size=10, max_steps=200):
        super(UAVClusterEnv, self).__init__()
        self.num_users = num_users
        self.num_uavs = num_uavs
        self.area_size = area_size
        self.max_steps = max_steps

        self.observation_space = spaces.Box(low=0, high=1, shape=(self.num_users + self.num_uavs, 2), dtype=np.float32)
        self.action_space = spaces.MultiDiscrete([5] * self.num_uavs)

        self.reset()

    def reset(self):
        self.users = np.random.rand(self.num_users, 2) * self.area_size
        kmeans = KMeans(n_clusters=self.num_uavs, n_init=10)
        kmeans.fit(self.users)
        self.uavs = kmeans.cluster_centers_

        self.user_velocities = np.random.uniform(-0.1, 0.1, (self.num_users, 2))
        self.current_step = 0
        return self._get_state()

    def step(self, action):
        self.current_step += 1
        boundary_penalty = self._update_uav_positions(action)
        self._update_user_positions()
        reward = self._calculate_reward()

        if boundary_penalty:
            reward -= 1

        done = self._is_done()

        return self._get_state(), reward, done, {}

    def _update_uav_positions(self, actions):
        boundary_penalty = False
        stepsize = 0.4
        for i in range(self.num_uavs):
            direction = actions[i]

            if direction == 0:
                self.uavs[i][1] += stepsize
            elif direction == 1:
                self.uavs[i][1] -= stepsize
            elif direction == 2:
                self.uavs[i][0] -= stepsize
            elif direction == 3:
                self.uavs[i][0] += stepsize

            if self.uavs[i][0] < 0 or self.uavs[i][0] > self.area_size or self.uavs[i][1] < 0 or self.uavs[i][1] > self.area_size:
                boundary_penalty = True

            self.uavs[i][0] = np.clip(self.uavs[i][0], 0, self.area_size)
            self.uavs[i][1] = np.clip(self.uavs[i][1], 0, self.area_size)

        return boundary_penalty

    def _update_user_positions(self):
        for i in range(self.num_users):
            self.users[i] += self.user_velocities[i]
            self._boundary_check(i)
            if np.linalg.norm(self.user_velocities[i]) < 0.05:
                self.user_velocities[i] += np.random.uniform(-0.1, 0.1, 2)

    def _boundary_check(self, i):
        if self.users[i][0] < 0:
            self.users[i][0] = 0
            self.user_velocities[i] = np.random.uniform(-0.1, 0.1, 2)  # Slowed down reallocated velocity
        elif self.users[i][0] > self.area_size:
            self.users[i][0] = self.area_size
            self.user_velocities[i] = np.random.uniform(-0.1, 0.1, 2)  # Slowed down reallocated velocity

        if self.users[i][1] < 0:
            self.users[i][1] = 0
            self.user_velocities[i] = np.random.uniform(-0.1, 0.1, 2)  # Slowed down reallocated velocity
        elif self.users[i][1] > self.area_size:
            self.users[i][1] = self.area_size
            self.user_velocities[i] = np.random.uniform(-0.1, 0.1, 2)  # Slowed down reallocated velocity

    def _is_done(self):
        return self.current_step >= self.max_steps

    def _get_state(self):
        return np.concatenate([self.users / self.area_size, self.uavs / self.area_size])

    def _calculate_reward(self):
        reward = 0
        coverage_radius = 3
        for user in self.users:
            distances = np.linalg.norm(self.uavs - user, axis=1)
            closest_distance = np.min(distances)
            if closest_distance < coverage_radius:
                reward += 1
            else:
                reward -= 1
        reward = np.clip(reward, -10, 10)
        return reward

    def render(self, mode='human'):
        pass

# %%
def train_dqn_agent(env, agent, n_episodes=500, max_steps_per_episode=200, stop_loss_threshold=0.01, patience=10):
    save_path = f"dqn_weights_users{env.num_users}_uavs{env.num_uavs}_area{env.area_size}.pth"
    losses = []
    rewards = []
    stop_loss_counter = 0

    for episode in range(n_episodes):
        state = env.reset()
        total_reward = 0
        episode_losses = []
        start_time = time.time()

        for step in range(max_steps_per_episode):
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            
            loss = agent.replay()
            if loss is not None:
                episode_losses.append(loss)
            
            if done:
                break

        avg_loss = np.mean(episode_losses) if episode_losses else 0
        epsilon = agent.epsilon

        rewards.append(total_reward)
        losses.append(avg_loss)

        end_time = time.time()
        episode_duration = end_time - start_time
        avg_reward = np.mean(rewards[-100:])

        print(f"Episode {episode + 1}/{n_episodes} | Epsilon: {epsilon:.2f} | "
              f"Avg Reward: {avg_reward:.2f} | Avg Loss: {avg_loss:.4f} | "
              f"Time: {episode_duration:.2f}s")

        if avg_loss < stop_loss_threshold:
            stop_loss_counter += 1
            print(f"stop loss counter: {stop_loss_counter}")
            if stop_loss_counter >= patience:
                print(f"Training stopped early at episode {episode + 1} due to consistently low loss.")
                break
        else:
            stop_loss_counter = 0

        if episode % 10 == 0:
            agent.update_target_model()

    torch.save(agent.model.state_dict(), save_path)
    print(f"Model weights saved to {save_path}")

    plt.figure(figsize=(10, 5))
    plt.plot(losses, label="Loss")
    plt.xlabel("Episode")
    plt.ylabel("Loss")
    plt.title("Loss per Episode")
    plt.legend()
    plt.show()

    return rewards, losses

# %%
# Create the environment and DQN agent
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
env = UAVClusterEnv(num_users=10, num_uavs=3, area_size=15)
state_size = np.prod(env.observation_space.shape)
action_size = np.prod(env.action_space.nvec)

# IF using non-existing model, use this code:
agent = DQNAgent(state_size, action_size)
agent.model.to(device)

# IF using existing model, uncomment this code:

# Initialize the model (make sure it matches the structure of the saved model)
# agent = DQNAgent(state_size, action_size)

# # Load the saved weights
# agent.model.load_state_dict(torch.load("dqn_weights.pth"))
# Out:
# QNetwork(
#   (fc1): Linear(in_features=26, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=125, bias=True)
# )

# %%
# Train the DQN agent
rewards, losses = train_dqn_agent(env, agent, n_episodes=300, max_steps_per_episode=300, stop_loss_threshold=0.0001)
# Out:
# Episode 1/300 | Epsilon: 0.50 | Avg Reward: -23.79 | Avg Loss: 0.0007 | Time: 6.24s
# Episode 2/300 | Epsilon: 0.18 | Avg Reward: -44.43 | Avg Loss: 0.0007 | Time: 8.83s
# Episode 3/300 | Epsilon: 0.07 | Avg Reward: -46.48 | Avg Loss: 0.0009 | Time: 8.94s
# Episode 4/300 | Epsilon: 0.02 | Avg Reward: -59.44 | Avg Loss: 0.0009 | Time: 9.11s
# Episode 5/300 | Epsilon: 0.01 | Avg Reward: -62.06 | Avg Loss: 0.0008 | Time: 9.44s
# Episode 6/300 | Epsilon: 0.01 | Avg Reward: -60.94 | Avg Loss: 0.0007 | Time: 8.92s
# Episode 7/300 | Epsilon: 0.01 | Avg Reward: -57.23 | Avg Loss: 0.0007 | Time: 8.80s
# Episode 8/300 | Epsilon: 0.01 | Avg Reward: -56.75 | Avg Loss: 0.0007 | Time: 8.53s
# Episode 9/300 | Epsilon: 0.01 | Avg Reward: -57.54 | Avg Loss: 0.0007 | Time: 8.60s
# Episode 10/300 | Epsilon: 0.01 | Avg Reward: -59.57 | Avg Loss: 0.0007 | Time: 8.56s
# Episode 11/300 | Epsilon: 0.01 | Avg Reward: -57.28 | Avg Loss: 0.0007 | Time: 8.54s
# Episode 12/300 | Epsilon: 0.01 | Avg Reward: -53.70 | Avg Loss: 0.0007 | Time: 8.51s
# Episode 13/300 | Epsilon: 0.01 | Avg Reward: -50.43 | Avg Loss: 0.0006 | Time: 8.84s
# Episode 14/300 | Epsilon: 0.01 | Avg Reward: -47.36 | Avg Loss: 0.0005 | Time: 8.52s
# Episode 15/300 | Epsilon: 0.01 | Avg Reward: -48.23 | Avg Loss: 0.0005 | Time: 8.81s
# Episode 16/300 | Epsilon: 0.01 | Avg Reward: -46.67 | Avg Loss: 0.0006 | Time: 8.84s
# Episode 17/300 | Epsilon: 0.01 | Avg Reward: -47.45 | Avg Loss: 0.0005 | Time: 8.56s
# Episode 18/300 | Epsilon: 0.01 | Avg Reward: -47.57 | Avg Loss: 0.0006 | Time: 8.54s
# Episode 19/300 | Epsilon: 0.01 | Avg Reward: -46.61 | Avg Loss: 0.0006 | Time: 8.94s
# Episode 20/300 | Epsilon: 0.01 | Avg Reward: -45.14 | Avg Loss: 0.0006 | Time: 8.56s
# Episode 21/300 | Epsilon: 0.01 | Avg Reward: -43.21 | Avg Loss: 0.0005 | Time: 8.52s
# Episode 22/300 | Epsilon: 0.01 | Avg Reward: -42.48 | Avg Loss: 0.0006 | Time: 9.61s
# Episode 23/300 | Epsilon: 0.01 | Avg Reward: -40.79 | Avg Loss: 0.0006 | Time: 8.84s
# Episode 24/300 | Epsilon: 0.01 | Avg Reward: -39.49 | Avg Loss: 0.0005 | Time: 8.53s
# Episode 25/300 | Epsilon: 0.01 | Avg Reward: -38.24 | Avg Loss: 0.0005 | Time: 8.78s
# Episode 26/300 | Epsilon: 0.01 | Avg Reward: -36.93 | Avg Loss: 0.0005 | Time: 8.72s
# Episode 27/300 | Epsilon: 0.01 | Avg Reward: -36.77 | Avg Loss: 0.0005 | Time: 8.48s
# Episode 28/300 | Epsilon: 0.01 | Avg Reward: -36.41 | Avg Loss: 0.0005 | Time: 8.63s
# Episode 29/300 | Epsilon: 0.01 | Avg Reward: -35.56 | Avg Loss: 0.0004 | Time: 8.60s
# Episode 30/300 | Epsilon: 0.01 | Avg Reward: -34.75 | Avg Loss: 0.0004 | Time: 8.50s
# Episode 31/300 | Epsilon: 0.01 | Avg Reward: -34.41 | Avg Loss: 0.0004 | Time: 9.60s
# Episode 32/300 | Epsilon: 0.01 | Avg Reward: -34.15 | Avg Loss: 0.0005 | Time: 8.52s
# Episode 33/300 | Epsilon: 0.01 | Avg Reward: -33.51 | Avg Loss: 0.0005 | Time: 8.49s
# Episode 34/300 | Epsilon: 0.01 | Avg Reward: -32.70 | Avg Loss: 0.0005 | Time: 8.54s
# Episode 35/300 | Epsilon: 0.01 | Avg Reward: -32.68 | Avg Loss: 0.0005 | Time: 8.62s
# Episode 36/300 | Epsilon: 0.01 | Avg Reward: -31.86 | Avg Loss: 0.0004 | Time: 8.52s
# Episode 37/300 | Epsilon: 0.01 | Avg Reward: -31.07 | Avg Loss: 0.0004 | Time: 8.95s
# Episode 38/300 | Epsilon: 0.01 | Avg Reward: -30.58 | Avg Loss: 0.0004 | Time: 9.25s
# Episode 39/300 | Epsilon: 0.01 | Avg Reward: -29.84 | Avg Loss: 0.0004 | Time: 8.84s
# Episode 40/300 | Epsilon: 0.01 | Avg Reward: -29.30 | Avg Loss: 0.0004 | Time: 8.66s
# Episode 41/300 | Epsilon: 0.01 | Avg Reward: -28.86 | Avg Loss: 0.0004 | Time: 8.62s
# Episode 42/300 | Epsilon: 0.01 | Avg Reward: -28.24 | Avg Loss: 0.0004 | Time: 9.30s
# Episode 43/300 | Epsilon: 0.01 | Avg Reward: -27.79 | Avg Loss: 0.0004 | Time: 8.87s
# Episode 44/300 | Epsilon: 0.01 | Avg Reward: -27.67 | Avg Loss: 0.0004 | Time: 8.51s
# Episode 45/300 | Epsilon: 0.01 | Avg Reward: -27.21 | Avg Loss: 0.0004 | Time: 8.58s
# Episode 46/300 | Epsilon: 0.01 | Avg Reward: -26.82 | Avg Loss: 0.0004 | Time: 9.05s
# Episode 47/300 | Epsilon: 0.01 | Avg Reward: -26.38 | Avg Loss: 0.0004 | Time: 8.52s
# Episode 48/300 | Epsilon: 0.01 | Avg Reward: -26.74 | Avg Loss: 0.0004 | Time: 8.53s
# Episode 49/300 | Epsilon: 0.01 | Avg Reward: -26.53 | Avg Loss: 0.0004 | Time: 8.49s
# Episode 50/300 | Epsilon: 0.01 | Avg Reward: -26.05 | Avg Loss: 0.0004 | Time: 8.83s
# Episode 51/300 | Epsilon: 0.01 | Avg Reward: -26.10 | Avg Loss: 0.0004 | Time: 8.52s
# Episode 52/300 | Epsilon: 0.01 | Avg Reward: -25.97 | Avg Loss: 0.0005 | Time: 8.53s
# Episode 53/300 | Epsilon: 0.01 | Avg Reward: -26.20 | Avg Loss: 0.0004 | Time: 8.62s
# Episode 54/300 | Epsilon: 0.01 | Avg Reward: -25.89 | Avg Loss: 0.0004 | Time: 8.77s
# Episode 55/300 | Epsilon: 0.01 | Avg Reward: -26.23 | Avg Loss: 0.0004 | Time: 8.42s
# Episode 56/300 | Epsilon: 0.01 | Avg Reward: -25.81 | Avg Loss: 0.0004 | Time: 8.60s
# Episode 57/300 | Epsilon: 0.01 | Avg Reward: -25.58 | Avg Loss: 0.0004 | Time: 8.86s
# Episode 58/300 | Epsilon: 0.01 | Avg Reward: -25.21 | Avg Loss: 0.0004 | Time: 8.53s
# Episode 59/300 | Epsilon: 0.01 | Avg Reward: -24.88 | Avg Loss: 0.0004 | Time: 8.69s
# Episode 60/300 | Epsilon: 0.01 | Avg Reward: -24.86 | Avg Loss: 0.0004 | Time: 8.98s
# Episode 61/300 | Epsilon: 0.01 | Avg Reward: -24.48 | Avg Loss: 0.0004 | Time: 8.61s
# Episode 62/300 | Epsilon: 0.01 | Avg Reward: -24.11 | Avg Loss: 0.0004 | Time: 8.47s
# Episode 63/300 | Epsilon: 0.01 | Avg Reward: -24.05 | Avg Loss: 0.0004 | Time: 8.51s
# Episode 64/300 | Epsilon: 0.01 | Avg Reward: -23.72 | Avg Loss: 0.0004 | Time: 8.70s
# Episode 65/300 | Epsilon: 0.01 | Avg Reward: -23.76 | Avg Loss: 0.0004 | Time: 8.92s
# Episode 66/300 | Epsilon: 0.01 | Avg Reward: -23.58 | Avg Loss: 0.0004 | Time: 8.58s
# Episode 67/300 | Epsilon: 0.01 | Avg Reward: -23.35 | Avg Loss: 0.0004 | Time: 9.06s
# Episode 68/300 | Epsilon: 0.01 | Avg Reward: -23.04 | Avg Loss: 0.0004 | Time: 8.55s
# Episode 69/300 | Epsilon: 0.01 | Avg Reward: -22.99 | Avg Loss: 0.0004 | Time: 8.83s
# Episode 70/300 | Epsilon: 0.01 | Avg Reward: -22.77 | Avg Loss: 0.0004 | Time: 8.54s
# Episode 71/300 | Epsilon: 0.01 | Avg Reward: -22.48 | Avg Loss: 0.0004 | Time: 8.81s
# Episode 72/300 | Epsilon: 0.01 | Avg Reward: -22.63 | Avg Loss: 0.0004 | Time: 8.51s
# Episode 73/300 | Epsilon: 0.01 | Avg Reward: -22.46 | Avg Loss: 0.0004 | Time: 8.59s
# Episode 74/300 | Epsilon: 0.01 | Avg Reward: -22.42 | Avg Loss: 0.0004 | Time: 8.76s
# Episode 75/300 | Epsilon: 0.01 | Avg Reward: -22.22 | Avg Loss: 0.0004 | Time: 8.50s
# Episode 76/300 | Epsilon: 0.01 | Avg Reward: -22.09 | Avg Loss: 0.0004 | Time: 8.55s
# Episode 77/300 | Epsilon: 0.01 | Avg Reward: -21.83 | Avg Loss: 0.0004 | Time: 8.70s
# Episode 78/300 | Epsilon: 0.01 | Avg Reward: -21.57 | Avg Loss: 0.0004 | Time: 10.76s
# Episode 79/300 | Epsilon: 0.01 | Avg Reward: -21.32 | Avg Loss: 0.0003 | Time: 13.86s
# Episode 80/300 | Epsilon: 0.01 | Avg Reward: -21.08 | Avg Loss: 0.0003 | Time: 9.07s
# Episode 81/300 | Epsilon: 0.01 | Avg Reward: -20.86 | Avg Loss: 0.0003 | Time: 9.61s
# Episode 82/300 | Epsilon: 0.01 | Avg Reward: -20.66 | Avg Loss: 0.0004 | Time: 8.90s
# Episode 83/300 | Epsilon: 0.01 | Avg Reward: -20.43 | Avg Loss: 0.0003 | Time: 9.21s
# Episode 84/300 | Epsilon: 0.01 | Avg Reward: -20.19 | Avg Loss: 0.0003 | Time: 9.18s
# Episode 85/300 | Epsilon: 0.01 | Avg Reward: -20.00 | Avg Loss: 0.0003 | Time: 8.62s
# Episode 86/300 | Epsilon: 0.01 | Avg Reward: -19.81 | Avg Loss: 0.0003 | Time: 8.64s
# Episode 87/300 | Epsilon: 0.01 | Avg Reward: -19.84 | Avg Loss: 0.0003 | Time: 9.01s
# Episode 88/300 | Epsilon: 0.01 | Avg Reward: -19.76 | Avg Loss: 0.0003 | Time: 8.64s
# Episode 89/300 | Epsilon: 0.01 | Avg Reward: -19.59 | Avg Loss: 0.0003 | Time: 8.77s
# Episode 90/300 | Epsilon: 0.01 | Avg Reward: -19.41 | Avg Loss: 0.0003 | Time: 8.65s
# Episode 91/300 | Epsilon: 0.01 | Avg Reward: -19.29 | Avg Loss: 0.0003 | Time: 8.53s
# Episode 92/300 | Epsilon: 0.01 | Avg Reward: -19.32 | Avg Loss: 0.0004 | Time: 9.12s
# Episode 93/300 | Epsilon: 0.01 | Avg Reward: -19.25 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 94/300 | Epsilon: 0.01 | Avg Reward: -19.17 | Avg Loss: 0.0003 | Time: 8.54s
# Episode 95/300 | Epsilon: 0.01 | Avg Reward: -18.98 | Avg Loss: 0.0003 | Time: 8.54s
# Episode 96/300 | Epsilon: 0.01 | Avg Reward: -18.80 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 97/300 | Epsilon: 0.01 | Avg Reward: -18.62 | Avg Loss: 0.0003 | Time: 8.80s
# Episode 98/300 | Epsilon: 0.01 | Avg Reward: -18.51 | Avg Loss: 0.0003 | Time: 8.82s
# Episode 99/300 | Epsilon: 0.01 | Avg Reward: -18.33 | Avg Loss: 0.0003 | Time: 8.56s
# Episode 100/300 | Epsilon: 0.01 | Avg Reward: -18.19 | Avg Loss: 0.0003 | Time: 8.55s
# Episode 101/300 | Epsilon: 0.01 | Avg Reward: -18.01 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 102/300 | Epsilon: 0.01 | Avg Reward: -17.39 | Avg Loss: 0.0003 | Time: 8.93s
# Episode 103/300 | Epsilon: 0.01 | Avg Reward: -16.91 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 104/300 | Epsilon: 0.01 | Avg Reward: -15.98 | Avg Loss: 0.0003 | Time: 8.54s
# Episode 105/300 | Epsilon: 0.01 | Avg Reward: -15.36 | Avg Loss: 0.0003 | Time: 8.59s
# Episode 106/300 | Epsilon: 0.01 | Avg Reward: -14.93 | Avg Loss: 0.0003 | Time: 8.55s
# Episode 107/300 | Epsilon: 0.01 | Avg Reward: -14.60 | Avg Loss: 0.0003 | Time: 8.59s
# Episode 108/300 | Epsilon: 0.01 | Avg Reward: -14.16 | Avg Loss: 0.0003 | Time: 8.64s
# Episode 109/300 | Epsilon: 0.01 | Avg Reward: -13.61 | Avg Loss: 0.0003 | Time: 8.64s
# Episode 110/300 | Epsilon: 0.01 | Avg Reward: -12.86 | Avg Loss: 0.0003 | Time: 8.52s
# Episode 111/300 | Epsilon: 0.01 | Avg Reward: -12.56 | Avg Loss: 0.0003 | Time: 8.69s
# Episode 112/300 | Epsilon: 0.01 | Avg Reward: -12.44 | Avg Loss: 0.0003 | Time: 8.52s
# Episode 113/300 | Epsilon: 0.01 | Avg Reward: -12.39 | Avg Loss: 0.0003 | Time: 8.86s
# Episode 114/300 | Epsilon: 0.01 | Avg Reward: -12.42 | Avg Loss: 0.0003 | Time: 8.65s
# Episode 115/300 | Epsilon: 0.01 | Avg Reward: -11.88 | Avg Loss: 0.0003 | Time: 8.66s
# Episode 116/300 | Epsilon: 0.01 | Avg Reward: -11.67 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 117/300 | Epsilon: 0.01 | Avg Reward: -11.12 | Avg Loss: 0.0003 | Time: 8.62s
# Episode 118/300 | Epsilon: 0.01 | Avg Reward: -10.67 | Avg Loss: 0.0003 | Time: 8.63s
# Episode 119/300 | Epsilon: 0.01 | Avg Reward: -10.82 | Avg Loss: 0.0003 | Time: 8.67s
# Episode 120/300 | Epsilon: 0.01 | Avg Reward: -10.66 | Avg Loss: 0.0003 | Time: 8.55s
# Episode 121/300 | Epsilon: 0.01 | Avg Reward: -10.71 | Avg Loss: 0.0003 | Time: 8.53s
# Episode 122/300 | Epsilon: 0.01 | Avg Reward: -10.49 | Avg Loss: 0.0003 | Time: 8.52s
# Episode 123/300 | Epsilon: 0.01 | Avg Reward: -10.82 | Avg Loss: 0.0003 | Time: 8.73s
# Episode 124/300 | Epsilon: 0.01 | Avg Reward: -10.75 | Avg Loss: 0.0003 | Time: 8.52s
# Episode 125/300 | Epsilon: 0.01 | Avg Reward: -10.68 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 126/300 | Epsilon: 0.01 | Avg Reward: -10.83 | Avg Loss: 0.0003 | Time: 8.58s
# Episode 127/300 | Epsilon: 0.01 | Avg Reward: -10.53 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 128/300 | Epsilon: 0.01 | Avg Reward: -10.38 | Avg Loss: 0.0003 | Time: 8.54s
# Episode 129/300 | Epsilon: 0.01 | Avg Reward: -10.30 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 130/300 | Epsilon: 0.01 | Avg Reward: -10.21 | Avg Loss: 0.0003 | Time: 8.78s
# Episode 131/300 | Epsilon: 0.01 | Avg Reward: -10.22 | Avg Loss: 0.0003 | Time: 8.55s
# Episode 132/300 | Epsilon: 0.01 | Avg Reward: -10.00 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 133/300 | Epsilon: 0.01 | Avg Reward: -9.91 | Avg Loss: 0.0003 | Time: 8.80s
# Episode 134/300 | Epsilon: 0.01 | Avg Reward: -9.91 | Avg Loss: 0.0003 | Time: 8.62s
# Episode 135/300 | Epsilon: 0.01 | Avg Reward: -9.61 | Avg Loss: 0.0003 | Time: 8.56s
# Episode 136/300 | Epsilon: 0.01 | Avg Reward: -9.73 | Avg Loss: 0.0003 | Time: 8.59s
# Episode 137/300 | Epsilon: 0.01 | Avg Reward: -9.73 | Avg Loss: 0.0003 | Time: 8.52s
# Episode 138/300 | Epsilon: 0.01 | Avg Reward: -9.71 | Avg Loss: 0.0003 | Time: 8.60s
# Episode 139/300 | Epsilon: 0.01 | Avg Reward: -9.71 | Avg Loss: 0.0003 | Time: 8.60s
# Episode 140/300 | Epsilon: 0.01 | Avg Reward: -9.70 | Avg Loss: 0.0003 | Time: 8.54s
# Episode 141/300 | Epsilon: 0.01 | Avg Reward: -9.61 | Avg Loss: 0.0003 | Time: 8.52s
# Episode 142/300 | Epsilon: 0.01 | Avg Reward: -9.76 | Avg Loss: 0.0003 | Time: 9.43s
# Episode 143/300 | Epsilon: 0.01 | Avg Reward: -9.72 | Avg Loss: 0.0003 | Time: 8.55s
# Episode 144/300 | Epsilon: 0.01 | Avg Reward: -9.70 | Avg Loss: 0.0003 | Time: 8.82s
# Episode 145/300 | Epsilon: 0.01 | Avg Reward: -9.77 | Avg Loss: 0.0003 | Time: 8.74s
# Episode 146/300 | Epsilon: 0.01 | Avg Reward: -9.91 | Avg Loss: 0.0003 | Time: 8.79s
# Episode 147/300 | Epsilon: 0.01 | Avg Reward: -9.90 | Avg Loss: 0.0003 | Time: 8.52s
# Episode 148/300 | Epsilon: 0.01 | Avg Reward: -9.47 | Avg Loss: 0.0003 | Time: 8.79s
# Episode 149/300 | Epsilon: 0.01 | Avg Reward: -9.36 | Avg Loss: 0.0003 | Time: 8.69s
# Episode 150/300 | Epsilon: 0.01 | Avg Reward: -9.36 | Avg Loss: 0.0003 | Time: 8.87s
# Episode 151/300 | Epsilon: 0.01 | Avg Reward: -9.08 | Avg Loss: 0.0003 | Time: 9.08s
# Episode 152/300 | Epsilon: 0.01 | Avg Reward: -8.90 | Avg Loss: 0.0003 | Time: 8.83s
# Episode 153/300 | Epsilon: 0.01 | Avg Reward: -8.68 | Avg Loss: 0.0003 | Time: 8.84s
# Episode 154/300 | Epsilon: 0.01 | Avg Reward: -8.60 | Avg Loss: 0.0003 | Time: 8.86s
# Episode 155/300 | Epsilon: 0.01 | Avg Reward: -8.29 | Avg Loss: 0.0003 | Time: 8.81s
# Episode 156/300 | Epsilon: 0.01 | Avg Reward: -8.30 | Avg Loss: 0.0003 | Time: 8.91s
# Episode 157/300 | Epsilon: 0.01 | Avg Reward: -8.28 | Avg Loss: 0.0003 | Time: 8.95s
# Episode 158/300 | Epsilon: 0.01 | Avg Reward: -8.29 | Avg Loss: 0.0003 | Time: 9.04s
# Episode 159/300 | Epsilon: 0.01 | Avg Reward: -8.25 | Avg Loss: 0.0003 | Time: 9.04s
# Episode 160/300 | Epsilon: 0.01 | Avg Reward: -8.05 | Avg Loss: 0.0003 | Time: 9.20s
# Episode 161/300 | Epsilon: 0.01 | Avg Reward: -8.05 | Avg Loss: 0.0003 | Time: 9.08s
# Episode 162/300 | Epsilon: 0.01 | Avg Reward: -8.09 | Avg Loss: 0.0003 | Time: 8.99s
# Episode 163/300 | Epsilon: 0.01 | Avg Reward: -7.91 | Avg Loss: 0.0003 | Time: 8.86s
# Episode 164/300 | Epsilon: 0.01 | Avg Reward: -7.96 | Avg Loss: 0.0003 | Time: 8.91s
# Episode 165/300 | Epsilon: 0.01 | Avg Reward: -7.70 | Avg Loss: 0.0003 | Time: 8.80s
# Episode 166/300 | Epsilon: 0.01 | Avg Reward: -7.64 | Avg Loss: 0.0003 | Time: 8.83s
# Episode 167/300 | Epsilon: 0.01 | Avg Reward: -7.59 | Avg Loss: 0.0003 | Time: 9.05s
# Episode 168/300 | Epsilon: 0.01 | Avg Reward: -7.69 | Avg Loss: 0.0003 | Time: 8.80s
# Episode 169/300 | Epsilon: 0.01 | Avg Reward: -7.53 | Avg Loss: 0.0003 | Time: 9.11s
# Episode 170/300 | Epsilon: 0.01 | Avg Reward: -7.53 | Avg Loss: 0.0003 | Time: 9.05s
# Episode 171/300 | Epsilon: 0.01 | Avg Reward: -7.76 | Avg Loss: 0.0003 | Time: 8.85s
# Episode 172/300 | Epsilon: 0.01 | Avg Reward: -7.47 | Avg Loss: 0.0004 | Time: 8.83s
# Episode 173/300 | Epsilon: 0.01 | Avg Reward: -7.38 | Avg Loss: 0.0003 | Time: 9.01s
# Episode 174/300 | Epsilon: 0.01 | Avg Reward: -7.31 | Avg Loss: 0.0004 | Time: 8.91s
# Episode 175/300 | Epsilon: 0.01 | Avg Reward: -7.24 | Avg Loss: 0.0003 | Time: 8.92s
# Episode 176/300 | Epsilon: 0.01 | Avg Reward: -7.14 | Avg Loss: 0.0003 | Time: 8.84s
# Episode 177/300 | Epsilon: 0.01 | Avg Reward: -7.27 | Avg Loss: 0.0003 | Time: 9.17s
# Episode 178/300 | Epsilon: 0.01 | Avg Reward: -7.28 | Avg Loss: 0.0003 | Time: 8.82s
# Episode 179/300 | Epsilon: 0.01 | Avg Reward: -7.44 | Avg Loss: 0.0003 | Time: 8.83s
# Episode 180/300 | Epsilon: 0.01 | Avg Reward: -7.59 | Avg Loss: 0.0003 | Time: 9.10s
# Episode 181/300 | Epsilon: 0.01 | Avg Reward: -7.60 | Avg Loss: 0.0003 | Time: 9.56s
# Episode 182/300 | Epsilon: 0.01 | Avg Reward: -7.56 | Avg Loss: 0.0004 | Time: 9.27s
# Episode 183/300 | Epsilon: 0.01 | Avg Reward: -7.60 | Avg Loss: 0.0003 | Time: 9.21s
# Episode 184/300 | Epsilon: 0.01 | Avg Reward: -7.61 | Avg Loss: 0.0003 | Time: 9.46s
# Episode 185/300 | Epsilon: 0.01 | Avg Reward: -7.67 | Avg Loss: 0.0003 | Time: 8.67s
# Episode 186/300 | Epsilon: 0.01 | Avg Reward: -7.64 | Avg Loss: 0.0003 | Time: 9.73s
# Episode 187/300 | Epsilon: 0.01 | Avg Reward: -7.44 | Avg Loss: 0.0003 | Time: 9.04s
# Episode 188/300 | Epsilon: 0.01 | Avg Reward: -7.48 | Avg Loss: 0.0003 | Time: 8.98s
# Episode 189/300 | Epsilon: 0.01 | Avg Reward: -7.46 | Avg Loss: 0.0003 | Time: 9.57s
# Episode 190/300 | Epsilon: 0.01 | Avg Reward: -7.43 | Avg Loss: 0.0003 | Time: 8.62s
# Episode 191/300 | Epsilon: 0.01 | Avg Reward: -7.37 | Avg Loss: 0.0003 | Time: 8.80s
# Episode 192/300 | Epsilon: 0.01 | Avg Reward: -7.18 | Avg Loss: 0.0004 | Time: 8.65s
# Episode 193/300 | Epsilon: 0.01 | Avg Reward: -7.13 | Avg Loss: 0.0004 | Time: 8.72s
# Episode 194/300 | Epsilon: 0.01 | Avg Reward: -7.09 | Avg Loss: 0.0003 | Time: 9.44s
# Episode 195/300 | Epsilon: 0.01 | Avg Reward: -7.17 | Avg Loss: 0.0003 | Time: 8.76s
# Episode 196/300 | Epsilon: 0.01 | Avg Reward: -7.33 | Avg Loss: 0.0003 | Time: 9.16s
# Episode 197/300 | Epsilon: 0.01 | Avg Reward: -7.33 | Avg Loss: 0.0003 | Time: 9.03s
# Episode 198/300 | Epsilon: 0.01 | Avg Reward: -7.27 | Avg Loss: 0.0003 | Time: 8.61s
# Episode 199/300 | Epsilon: 0.01 | Avg Reward: -7.28 | Avg Loss: 0.0003 | Time: 9.42s
# Episode 200/300 | Epsilon: 0.01 | Avg Reward: -7.43 | Avg Loss: 0.0003 | Time: 8.75s
# Episode 201/300 | Epsilon: 0.01 | Avg Reward: -7.48 | Avg Loss: 0.0003 | Time: 8.92s
# Episode 202/300 | Epsilon: 0.01 | Avg Reward: -7.49 | Avg Loss: 0.0004 | Time: 8.55s
# Episode 203/300 | Epsilon: 0.01 | Avg Reward: -7.78 | Avg Loss: 0.0004 | Time: 9.02s
# Episode 204/300 | Epsilon: 0.01 | Avg Reward: -7.77 | Avg Loss: 0.0004 | Time: 8.90s
# Episode 205/300 | Epsilon: 0.01 | Avg Reward: -7.70 | Avg Loss: 0.0004 | Time: 8.56s
# Episode 206/300 | Epsilon: 0.01 | Avg Reward: -7.60 | Avg Loss: 0.0003 | Time: 8.53s
# Episode 207/300 | Epsilon: 0.01 | Avg Reward: -7.64 | Avg Loss: 0.0003 | Time: 8.62s
# Episode 208/300 | Epsilon: 0.01 | Avg Reward: -7.68 | Avg Loss: 0.0003 | Time: 8.55s
# Episode 209/300 | Epsilon: 0.01 | Avg Reward: -7.61 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 210/300 | Epsilon: 0.01 | Avg Reward: -7.69 | Avg Loss: 0.0003 | Time: 8.50s
# Episode 211/300 | Epsilon: 0.01 | Avg Reward: -7.69 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 212/300 | Epsilon: 0.01 | Avg Reward: -7.70 | Avg Loss: 0.0003 | Time: 8.53s
# Episode 213/300 | Epsilon: 0.01 | Avg Reward: -7.67 | Avg Loss: 0.0004 | Time: 8.51s
# Episode 214/300 | Epsilon: 0.01 | Avg Reward: -7.68 | Avg Loss: 0.0004 | Time: 9.18s
# Episode 215/300 | Epsilon: 0.01 | Avg Reward: -7.81 | Avg Loss: 0.0004 | Time: 8.47s
# Episode 216/300 | Epsilon: 0.01 | Avg Reward: -7.81 | Avg Loss: 0.0004 | Time: 8.51s
# Episode 217/300 | Epsilon: 0.01 | Avg Reward: -7.80 | Avg Loss: 0.0003 | Time: 8.71s
# Episode 218/300 | Epsilon: 0.01 | Avg Reward: -7.76 | Avg Loss: 0.0003 | Time: 8.52s
# Episode 219/300 | Epsilon: 0.01 | Avg Reward: -7.42 | Avg Loss: 0.0003 | Time: 8.64s
# Episode 220/300 | Epsilon: 0.01 | Avg Reward: -7.49 | Avg Loss: 0.0003 | Time: 8.49s
# Episode 221/300 | Epsilon: 0.01 | Avg Reward: -7.56 | Avg Loss: 0.0003 | Time: 8.42s
# Episode 222/300 | Epsilon: 0.01 | Avg Reward: -7.68 | Avg Loss: 0.0004 | Time: 8.43s
# Episode 223/300 | Epsilon: 0.01 | Avg Reward: -7.41 | Avg Loss: 0.0004 | Time: 8.51s
# Episode 224/300 | Epsilon: 0.01 | Avg Reward: -7.41 | Avg Loss: 0.0004 | Time: 8.92s
# Episode 225/300 | Epsilon: 0.01 | Avg Reward: -7.41 | Avg Loss: 0.0003 | Time: 8.53s
# Episode 226/300 | Epsilon: 0.01 | Avg Reward: -7.26 | Avg Loss: 0.0003 | Time: 8.57s
# Episode 227/300 | Epsilon: 0.01 | Avg Reward: -7.27 | Avg Loss: 0.0003 | Time: 8.64s
# Episode 228/300 | Epsilon: 0.01 | Avg Reward: -7.29 | Avg Loss: 0.0003 | Time: 8.77s
# Episode 229/300 | Epsilon: 0.01 | Avg Reward: -7.33 | Avg Loss: 0.0003 | Time: 8.78s
# Episode 230/300 | Epsilon: 0.01 | Avg Reward: -7.43 | Avg Loss: 0.0003 | Time: 8.57s
# Episode 231/300 | Epsilon: 0.01 | Avg Reward: -7.23 | Avg Loss: 0.0004 | Time: 8.59s
# Episode 232/300 | Epsilon: 0.01 | Avg Reward: -7.27 | Avg Loss: 0.0004 | Time: 8.53s
# Episode 233/300 | Epsilon: 0.01 | Avg Reward: -7.25 | Avg Loss: 0.0004 | Time: 8.54s
# Episode 234/300 | Epsilon: 0.01 | Avg Reward: -7.30 | Avg Loss: 0.0004 | Time: 8.54s
# Episode 235/300 | Epsilon: 0.01 | Avg Reward: -7.48 | Avg Loss: 0.0004 | Time: 8.54s
# Episode 236/300 | Epsilon: 0.01 | Avg Reward: -7.37 | Avg Loss: 0.0004 | Time: 8.49s
# Episode 237/300 | Epsilon: 0.01 | Avg Reward: -7.38 | Avg Loss: 0.0004 | Time: 8.50s
# Episode 238/300 | Epsilon: 0.01 | Avg Reward: -7.35 | Avg Loss: 0.0003 | Time: 9.14s
# Episode 239/300 | Epsilon: 0.01 | Avg Reward: -7.36 | Avg Loss: 0.0003 | Time: 8.55s
# Episode 240/300 | Epsilon: 0.01 | Avg Reward: -7.37 | Avg Loss: 0.0004 | Time: 8.52s
# Episode 241/300 | Epsilon: 0.01 | Avg Reward: -7.49 | Avg Loss: 0.0004 | Time: 8.53s
# Episode 242/300 | Epsilon: 0.01 | Avg Reward: -7.44 | Avg Loss: 0.0004 | Time: 9.31s
# Episode 243/300 | Epsilon: 0.01 | Avg Reward: -7.59 | Avg Loss: 0.0004 | Time: 8.93s
# Episode 244/300 | Epsilon: 0.01 | Avg Reward: -7.39 | Avg Loss: 0.0004 | Time: 8.85s
# Episode 245/300 | Epsilon: 0.01 | Avg Reward: -7.27 | Avg Loss: 0.0004 | Time: 8.82s
# Episode 246/300 | Epsilon: 0.01 | Avg Reward: -7.08 | Avg Loss: 0.0004 | Time: 8.77s
# Episode 247/300 | Epsilon: 0.01 | Avg Reward: -7.11 | Avg Loss: 0.0004 | Time: 8.87s
# Episode 248/300 | Epsilon: 0.01 | Avg Reward: -7.37 | Avg Loss: 0.0004 | Time: 8.81s
# Episode 249/300 | Epsilon: 0.01 | Avg Reward: -7.39 | Avg Loss: 0.0004 | Time: 8.80s
# Episode 250/300 | Epsilon: 0.01 | Avg Reward: -7.43 | Avg Loss: 0.0004 | Time: 8.78s
# Episode 251/300 | Epsilon: 0.01 | Avg Reward: -7.44 | Avg Loss: 0.0004 | Time: 8.87s
# Episode 252/300 | Epsilon: 0.01 | Avg Reward: -7.47 | Avg Loss: 0.0004 | Time: 8.86s
# Episode 253/300 | Epsilon: 0.01 | Avg Reward: -7.35 | Avg Loss: 0.0004 | Time: 9.36s
# Episode 254/300 | Epsilon: 0.01 | Avg Reward: -7.33 | Avg Loss: 0.0004 | Time: 8.80s
# Episode 255/300 | Epsilon: 0.01 | Avg Reward: -7.23 | Avg Loss: 0.0004 | Time: 8.77s
# Episode 256/300 | Epsilon: 0.01 | Avg Reward: -7.21 | Avg Loss: 0.0003 | Time: 9.03s
# Episode 257/300 | Epsilon: 0.01 | Avg Reward: -7.37 | Avg Loss: 0.0004 | Time: 9.12s
# Episode 258/300 | Epsilon: 0.01 | Avg Reward: -7.35 | Avg Loss: 0.0003 | Time: 8.95s
# Episode 259/300 | Epsilon: 0.01 | Avg Reward: -7.34 | Avg Loss: 0.0004 | Time: 8.78s
# Episode 260/300 | Epsilon: 0.01 | Avg Reward: -7.47 | Avg Loss: 0.0004 | Time: 8.75s
# Episode 261/300 | Epsilon: 0.01 | Avg Reward: -7.57 | Avg Loss: 0.0004 | Time: 8.79s
# Episode 262/300 | Epsilon: 0.01 | Avg Reward: -7.54 | Avg Loss: 0.0004 | Time: 8.81s
# Episode 263/300 | Epsilon: 0.01 | Avg Reward: -7.55 | Avg Loss: 0.0004 | Time: 8.84s
# Episode 264/300 | Epsilon: 0.01 | Avg Reward: -7.53 | Avg Loss: 0.0004 | Time: 8.78s
# Episode 265/300 | Epsilon: 0.01 | Avg Reward: -7.56 | Avg Loss: 0.0004 | Time: 8.82s
# Episode 266/300 | Epsilon: 0.01 | Avg Reward: -7.52 | Avg Loss: 0.0004 | Time: 8.87s
# Episode 267/300 | Epsilon: 0.01 | Avg Reward: -7.56 | Avg Loss: 0.0004 | Time: 8.96s
# Episode 268/300 | Epsilon: 0.01 | Avg Reward: -7.47 | Avg Loss: 0.0004 | Time: 8.81s
# Episode 269/300 | Epsilon: 0.01 | Avg Reward: -7.45 | Avg Loss: 0.0004 | Time: 9.35s
# Episode 270/300 | Epsilon: 0.01 | Avg Reward: -7.45 | Avg Loss: 0.0004 | Time: 9.17s
# Episode 271/300 | Epsilon: 0.01 | Avg Reward: -7.26 | Avg Loss: 0.0003 | Time: 9.39s
# Episode 272/300 | Epsilon: 0.01 | Avg Reward: -7.27 | Avg Loss: 0.0004 | Time: 9.98s
# Episode 273/300 | Epsilon: 0.01 | Avg Reward: -7.29 | Avg Loss: 0.0004 | Time: 9.07s
# Episode 274/300 | Epsilon: 0.01 | Avg Reward: -7.28 | Avg Loss: 0.0004 | Time: 8.76s
# Episode 275/300 | Epsilon: 0.01 | Avg Reward: -7.29 | Avg Loss: 0.0003 | Time: 8.54s
# Episode 276/300 | Epsilon: 0.01 | Avg Reward: -7.34 | Avg Loss: 0.0004 | Time: 8.47s
# Episode 277/300 | Epsilon: 0.01 | Avg Reward: -7.21 | Avg Loss: 0.0004 | Time: 8.55s
# Episode 278/300 | Epsilon: 0.01 | Avg Reward: -7.24 | Avg Loss: 0.0004 | Time: 8.62s
# Episode 279/300 | Epsilon: 0.01 | Avg Reward: -7.08 | Avg Loss: 0.0004 | Time: 8.73s
# Episode 280/300 | Epsilon: 0.01 | Avg Reward: -6.97 | Avg Loss: 0.0003 | Time: 8.91s
# Episode 281/300 | Epsilon: 0.01 | Avg Reward: -6.96 | Avg Loss: 0.0004 | Time: 8.54s
# Episode 282/300 | Epsilon: 0.01 | Avg Reward: -7.14 | Avg Loss: 0.0004 | Time: 8.80s
# Episode 283/300 | Epsilon: 0.01 | Avg Reward: -7.10 | Avg Loss: 0.0004 | Time: 8.54s
# Episode 284/300 | Epsilon: 0.01 | Avg Reward: -7.10 | Avg Loss: 0.0004 | Time: 9.05s
# Episode 285/300 | Epsilon: 0.01 | Avg Reward: -7.08 | Avg Loss: 0.0003 | Time: 8.53s
# Episode 286/300 | Epsilon: 0.01 | Avg Reward: -7.08 | Avg Loss: 0.0004 | Time: 8.50s
# Episode 287/300 | Epsilon: 0.01 | Avg Reward: -7.17 | Avg Loss: 0.0004 | Time: 8.56s
# Episode 288/300 | Epsilon: 0.01 | Avg Reward: -7.03 | Avg Loss: 0.0003 | Time: 9.37s
# Episode 289/300 | Epsilon: 0.01 | Avg Reward: -7.06 | Avg Loss: 0.0004 | Time: 8.53s
# Episode 290/300 | Epsilon: 0.01 | Avg Reward: -7.13 | Avg Loss: 0.0004 | Time: 8.59s
# Episode 291/300 | Epsilon: 0.01 | Avg Reward: -7.10 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 292/300 | Epsilon: 0.01 | Avg Reward: -7.26 | Avg Loss: 0.0004 | Time: 8.53s
# Episode 293/300 | Epsilon: 0.01 | Avg Reward: -7.19 | Avg Loss: 0.0004 | Time: 8.51s
# Episode 294/300 | Epsilon: 0.01 | Avg Reward: -7.19 | Avg Loss: 0.0004 | Time: 9.08s
# Episode 295/300 | Epsilon: 0.01 | Avg Reward: -7.12 | Avg Loss: 0.0004 | Time: 8.69s
# Episode 296/300 | Epsilon: 0.01 | Avg Reward: -6.99 | Avg Loss: 0.0004 | Time: 8.49s
# Episode 297/300 | Epsilon: 0.01 | Avg Reward: -7.12 | Avg Loss: 0.0004 | Time: 8.69s
# Episode 298/300 | Epsilon: 0.01 | Avg Reward: -7.23 | Avg Loss: 0.0004 | Time: 8.52s
# Episode 299/300 | Epsilon: 0.01 | Avg Reward: -7.32 | Avg Loss: 0.0003 | Time: 8.51s
# Episode 300/300 | Epsilon: 0.01 | Avg Reward: -7.14 | Avg Loss: 0.0003 | Time: 9.23s
# Model weights saved to dqn_weights_users10_uavs3_area15.pth

# %%
def test_dqn_agent(env, agent, n_episodes=5, max_steps_per_episode=100):
    """
    Test the DQN agent in the environment for a given number of episodes with visualization.
    
    Args:
        env: The environment to test in.
        agent: The DQN agent.
        n_episodes: Number of episodes to run.
        max_steps_per_episode: Maximum number of steps per episode.
    
    Returns:
        total_rewards: List of total rewards obtained in each episode.
        metrics: Dictionary containing various evaluation metrics.
    """
    total_rewards = []
    avg_user_distances = []
    coverage_overlaps = []
    coverage_uniformities = []
    normalized_rewards = []

    for episode in range(n_episodes):
        state = env.reset()
        total_reward = 0

        for step in range(max_steps_per_episode):
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            total_reward += reward

            # Clear the previous plot
            clear_output(wait=True)

            # Plot the environment
            plt.figure(figsize=(8, 8))
            plt.xlim(0, env.area_size)
            plt.ylim(0, env.area_size)
            plt.scatter(env.users[:, 0], env.users[:, 1], color='blue', label='Users')
            plt.scatter(env.uavs[:, 0], env.uavs[:, 1], color='red', label='UAVs')

            # Calculate and plot distances/rewards
            total_coverage = np.zeros(env.users.shape[0])
            for i, uav in enumerate(env.uavs):
                distances = np.linalg.norm(env.users - uav, axis=1)
                coverage = np.exp(-distances)  # Exponential decay with distance
                total_coverage += coverage

                for j, user in enumerate(env.users):
                    plt.plot([uav[0], user[0]], [uav[1], user[1]], 'k-', lw=0.5)
                    plt.text((uav[0] + user[0]) / 2, (uav[1] + user[1]) / 2, f'{coverage[j]:.2f}', fontsize=8, color='green')

            # Plot coverage as a color intensity for each user
            plt.scatter(env.users[:, 0], env.users[:, 1], c=total_coverage, cmap='coolwarm', s=200, alpha=0.6, edgecolor='black')
            plt.colorbar(label='Coverage Intensity')

            plt.title(f'Episode {episode + 1}, Step {step + 1}')
            plt.legend()
            plt.show()

            state = next_state

            if done:
                break

        # Calculate metrics after the episode
        avg_distance = np.mean([np.min(np.linalg.norm(env.users - uav, axis=1)) for uav in env.uavs])
        coverage_overlap = sum(
            [max(0, env.area_size / 3 - np.linalg.norm(env.uavs[i] - env.uavs[j]))
             for i in range(len(env.uavs)) for j in range(i + 1, len(env.uavs))]
        )
        user_counts = np.zeros(len(env.uavs))
        for user in env.users:
            nearest_uav_idx = np.argmin(np.linalg.norm(env.uavs - user, axis=1))
            user_counts[nearest_uav_idx] += 1
        coverage_uniformity = np.var(user_counts)
        normalized_reward = total_reward / (len(env.users) * len(env.uavs))

        # Store the metrics
        avg_user_distances.append(avg_distance)
        coverage_overlaps.append(coverage_overlap)
        coverage_uniformities.append(coverage_uniformity)
        normalized_rewards.append(normalized_reward)

        total_rewards.append(total_reward)
        print(f"Test Episode {episode + 1}/{n_episodes} | Total Reward: {total_reward:.2f} | Avg Distance: {avg_distance:.2f} | "
              f"Overlap: {coverage_overlap:.2f} | Uniformity: {coverage_uniformity:.2f} | Normalized Reward: {normalized_reward:.4f}")

    avg_reward = np.mean(total_rewards)
    avg_distance = np.mean(avg_user_distances)
    avg_overlap = np.mean(coverage_overlaps)
    avg_uniformity = np.mean(coverage_uniformities)
    avg_normalized_reward = np.mean(normalized_rewards)

    print(f"\nAverage Reward over {n_episodes} Test Episodes: {avg_reward:.2f}")
    print(f"Average User Distance: {avg_distance:.2f}")
    print(f"Average Coverage Overlap: {avg_overlap:.2f}")
    print(f"Average Coverage Uniformity: {avg_uniformity:.2f}")
    print(f"Average Normalized Reward: {avg_normalized_reward:.4f}")

    metrics = {
        "avg_reward": avg_reward,
        "avg_distance": avg_distance,
        "avg_overlap": avg_overlap,
        "avg_uniformity": avg_uniformity,
        "avg_normalized_reward": avg_normalized_reward
    }
    
    return total_rewards, metrics

# %%
test_rewards = test_dqn_agent(env, agent, n_episodes=5, max_steps_per_episode=100)
# Out:
# Test Episode 15/15 | Total Reward: -4.35
#
# Average Reward over 15 Test Episodes: -6.68
